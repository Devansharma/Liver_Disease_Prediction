# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/devansh/workspace/Liver_prediction/input/indian_liver_patient.csv')
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
df.tail()
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 578   60   Male              0.5               0.1                   500
# 579   40   Male              0.6               0.1                    98
# 580   52   Male              0.8               0.2                   245
# 581   31   Male              1.3               0.5                   184
# 582   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# ...

# %%
print('Row: ',df.shape[0])
print('Columns: ', df.shape[1])
print('\nFeatues: ', df.columns.tolist())
print('\nMissing Values: ', df.isnull().any())
print('\nUnique Values: ', df.nunique())
# Out:
# Row:  583
# Columns:  11
#
# Featues:  ['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin', 'Alkaline_Phosphotase', 'Alamine_Aminotransferase', 'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin', 'Albumin_and_Globulin_Ratio', 'Dataset']
#
# Missing Values:  Age                           False
# Gender                        False
# Total_Bilirubin               False
# Direct_Bilirubin              False
# Alkaline_Phosphotase          False
# Alamine_Aminotransferase      False
# Aspartate_Aminotransferase    False
# Total_Protiens                False
# Albumin                       False
# Albumin_and_Globulin_Ratio     True
# Dataset                       False
# dtype: bool
#
# Unique Values:  Age                            72
# Gender                          2
# Total_Bilirubin               113
# Direct_Bilirubin               80
# Alkaline_Phosphotase          263
# Alamine_Aminotransferase      152
# Aspartate_Aminotransferase    177
# ...

# %%
sns.pairplot(df)

# %%
corr = df.corr()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(corr, annot=True, cbar=False)

# %%
df[['Albumin', 'Albumin_and_Globulin_Ratio']].corr()
# Out:
#                              Albumin  Albumin_and_Globulin_Ratio
# Albumin                     1.000000                    0.689632
# Albumin_and_Globulin_Ratio  0.689632                    1.000000

# %%
sns.lmplot(x='Albumin_and_Globulin_Ratio', y='Alamine_Aminotransferase', data=df, fit_reg=True,
           col = 'Dataset', hue = 'Dataset', line_kws={'color':'red'})

# %%
df['Dataset'].replace({1:1, 2:0},inplace=True)

# %%
df.tail()
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 578   60   Male              0.5               0.1                   500
# 579   40   Male              0.6               0.1                    98
# 580   52   Male              0.8               0.2                   245
# 581   31   Male              1.3               0.5                   184
# 582   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# ...

# %%
from sklearn import preprocessing

# %%
encoder = preprocessing.LabelEncoder()
df['Gender'] = encoder.fit_transform(df['Gender'])
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65       0              0.7               0.1                   187
# 1   62       1             10.9               5.5                   699
# 2   62       1              7.3               4.1                   490
# 3   58       1              1.0               0.4                   182
# 4   72       1              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...
